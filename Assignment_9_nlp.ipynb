# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHI2303A51/batch30/blob/main/Assignment_9_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical

# Parameters
batch_size = 64
epochs = 100
latent_dim = 256
input_vocab_size = 100  # adjust based on actual vocab size
target_vocab_size = 100  # adjust based on actual vocab size

# Sample data (use your own dataset)
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# Vocabulary creation
input_texts = [pair[0] for pair in data]
target_texts = [pair[1] for pair in data]

# Create a mapping of unique tokens for both input and target sequences
input_tokens = sorted(set(" ".join(input_texts).split()))
target_tokens = sorted(set(" ".join(target_texts).split()))

input_token_index = dict([(char, i + 1) for i, char in enumerate(input_tokens)])
target_token_index = dict([(char, i + 1) for i, char in enumerate(target_tokens)])

input_vocab_size = len(input_token_index) + 1
target_vocab_size = len(target_token_index) + 1

# Encode sentences into sequences of integers
def encode_text(text, token_index, max_len):
    sequence = [token_index[word] for word in text.split() if word in token_index]
    sequence = sequence + [0] * (max_len - len(sequence))  # Pad sequences
    return sequence

# Determine maximum lengths for padding
max_encoder_seq_length = max([len(text.split()) for text in input_texts])
max_decoder_seq_length = max([len(text.split()) for text in target_texts])

# Prepare the data
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype="int32")
decoder_input_data = np.zeros((len(target_texts), max_decoder_seq_length), dtype="int32")
decoder_target_data = np.zeros((len(target_texts), max_decoder_seq_length, target_vocab_size), dtype="float32")

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    encoder_input_data[i] = encode_text(input_text, input_token_index, max_encoder_seq_length)
    decoder_input_data[i] = encode_text(target_text, target_token_index, max_decoder_seq_length)
    for t, word in enumerate(target_text.split()):
        if word in target_token_index:
            decoder_target_data[i, t, target_token_index[word]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[word]] = 1.0  # Shifts the target sequence

# Model definition
# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(input_dim=input_vocab_size, output_dim=latent_dim)(encoder_inputs)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(input_dim=target_vocab_size, output_dim=latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(target_vocab_size, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer=RMSprop(), loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# Inference models
# Encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model for inference
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# Translation function
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))
    start_token_index = 1 if target_token_index else 0  # Default to 0 if empty
    target_seq[0, 0] = start_token_index

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        reverse_target_token_index = dict((i, char) for char, i in target_token_index.items())
        sampled_word = reverse_target_token_index[sampled_token_index]
        decoded_sentence += ' ' + sampled_word

        # Exit condition: either hit max length or find stop character.
        if (sampled_word == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()

# Test the translation
test_input_seq = np.array(encode_text("hello", input_token_index, max_encoder_seq_length)).reshape(1, -1)
translated_sentence = decode_sequence(test_input_seq)
print("Translated sentence:", translated_sentence)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.0667 - loss: 3.3432 - val_accuracy: 0.0000e+00 - val_loss: 1.7812
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4667 - loss: 3.2955 - val_accuracy: 0.0000e+00 - val_loss: 1.7971
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.5333 - loss: 3.2534 - val_accuracy: 0.0000e+00 - val_loss: 1.8129
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 3.2103 - val_accuracy: 0.0000e+00 - val_loss: 1.8299
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5333 - loss: 3.1627 - val_accuracy: 0.0000e+00 - val_loss: 1.8491
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5333 - loss: 3.1083 - val_accuracy: 0.0000e+00 - val_loss: 1.8712
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5333 - loss: 3.0446 - val_accuracy: 0.0000e+00 - val_loss: 1.8969
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5333 - loss: 2.9689 - val_accuracy: 0.0000e+00 - val_loss: 1.9270
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5333 - loss: 2.8780 - val_accuracy: 0.0000e+00 - val_loss: 1.9624
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5333 - loss: 2.7686 - val_accuracy: 0.0000e+00 - val_loss: 2.0036
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5333 - loss: 2.6373 - val_accuracy: 0.0000e+00 - val_loss: 2.0511
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.5333 - loss: 2.4817 - val_accuracy: 0.0000e+00 - val_loss: 2.1048
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.5333 - loss: 2.3033 - val_accuracy: 0.0000e+00 - val_loss: 2.1643
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.5333 - loss: 2.1108 - val_accuracy: 0.0000e+00 - val_loss: 2.2289
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5333 - loss: 1.9209 - val_accuracy: 0.0000e+00 - val_loss: 2.2970
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 1.7517 - val_accuracy: 0.0000e+00 - val_loss: 2.3658
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.5333 - loss: 1.6122 - val_accuracy: 0.0000e+00 - val_loss: 2.4333
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.5333 - loss: 1.5007 - val_accuracy: 0.0000e+00 - val_loss: 2.4999
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5333 - loss: 1.4109 - val_accuracy: 0.0000e+00 - val_loss: 2.5694
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5333 - loss: 1.3375 - val_accuracy: 0.0000e+00 - val_loss: 2.6468
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.5333 - loss: 1.2764 - val_accuracy: 0.0000e+00 - val_loss: 2.7386
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5333 - loss: 1.2237 - val_accuracy: 0.0000e+00 - val_loss: 2.8530
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.1754 - val_accuracy: 0.0000e+00 - val_loss: 3.0004
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5333 - loss: 1.1272 - val_accuracy: 0.0000e+00 - val_loss: 3.1934
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.5333 - loss: 1.0769 - val_accuracy: 0.0000e+00 - val_loss: 3.4445
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5333 - loss: 1.0247 - val_accuracy: 0.0000e+00 - val_loss: 3.7559
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5333 - loss: 0.9754 - val_accuracy: 0.0000e+00 - val_loss: 4.2955
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4000 - loss: 1.2613 - val_accuracy: 0.0000e+00 - val_loss: 4.2539
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 1.1014 - val_accuracy: 0.0000e+00 - val_loss: 4.7782
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5333 - loss: 0.9477 - val_accuracy: 0.0000e+00 - val_loss: 4.9081
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5333 - loss: 0.8586 - val_accuracy: 0.0000e+00 - val_loss: 5.4576
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4667 - loss: 0.8426 - val_accuracy: 0.0000e+00 - val_loss: 5.5256
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 1.2761 - val_accuracy: 0.0000e+00 - val_loss: 5.9106
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6000 - loss: 0.8864 - val_accuracy: 0.0000e+00 - val_loss: 6.2554
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.4667 - loss: 0.8552 - val_accuracy: 0.0000e+00 - val_loss: 6.4148
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 0.8248 - val_accuracy: 0.0000e+00 - val_loss: 7.3103
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4667 - loss: 1.1888 - val_accuracy: 0.0000e+00 - val_loss: 6.8644
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4667 - loss: 0.9502 - val_accuracy: 0.0000e+00 - val_loss: 7.2977
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4667 - loss: 0.8962 - val_accuracy: 0.0000e+00 - val_loss: 7.4349
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3333 - loss: 0.8005 - val_accuracy: 0.0000e+00 - val_loss: 7.7703
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 0.7744 - val_accuracy: 0.0000e+00 - val_loss: 8.0417
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4667 - loss: 0.7821 - val_accuracy: 0.0000e+00 - val_loss: 8.3531
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.4000 - loss: 0.7646 - val_accuracy: 0.0000e+00 - val_loss: 8.5921
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4667 - loss: 0.7785 - val_accuracy: 0.0000e+00 - val_loss: 8.8645
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4000 - loss: 0.7619 - val_accuracy: 0.0000e+00 - val_loss: 9.2103
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5333 - loss: 0.8700 - val_accuracy: 0.0000e+00 - val_loss: 9.2878
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5333 - loss: 0.9100 - val_accuracy: 0.0000e+00 - val_loss: 9.4893
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4667 - loss: 0.8175 - val_accuracy: 0.0000e+00 - val_loss: 9.9408
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4000 - loss: 0.7778 - val_accuracy: 0.0000e+00 - val_loss: 10.1284
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.4000 - loss: 0.7634 - val_accuracy: 0.0000e+00 - val_loss: 10.4888
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4000 - loss: 0.7476 - val_accuracy: 0.0000e+00 - val_loss: 10.7134
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 0.7579 - val_accuracy: 0.0000e+00 - val_loss: 11.0777
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.3333 - loss: 0.7410 - val_accuracy: 0.0000e+00 - val_loss: 11.2952
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 0.7640 - val_accuracy: 0.0000e+00 - val_loss: 11.6503
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.3333 - loss: 0.7403 - val_accuracy: 0.0000e+00 - val_loss: 11.8841
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5333 - loss: 0.7836 - val_accuracy: 0.0000e+00 - val_loss: 12.0811
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3333 - loss: 0.7481 - val_accuracy: 0.0000e+00 - val_loss: 12.5329
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5333 - loss: 0.7997 - val_accuracy: 0.0000e+00 - val_loss: 12.2206
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3333 - loss: 0.7679 - val_accuracy: 0.0000e+00 - val_loss: 13.0666
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5333 - loss: 0.7598 - val_accuracy: 0.0000e+00 - val_loss: 12.9735
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.3333 - loss: 0.7320 - val_accuracy: 0.0000e+00 - val_loss: 13.5706
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 0.7514 - val_accuracy: 0.0000e+00 - val_loss: 13.4566
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.3333 - loss: 0.7268 - val_accuracy: 0.0000e+00 - val_loss: 14.0620
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 0.7826 - val_accuracy: 0.0000e+00 - val_loss: 13.8887
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.4667 - loss: 0.7455 - val_accuracy: 0.0000e+00 - val_loss: 14.2590
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5333 - loss: 0.8208 - val_accuracy: 0.0000e+00 - val_loss: 14.3571
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4000 - loss: 0.7515 - val_accuracy: 0.0000e+00 - val_loss: 14.5656
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4667 - loss: 0.7813 - val_accuracy: 0.0000e+00 - val_loss: 14.5657
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4000 - loss: 0.7164 - val_accuracy: 0.0000e+00 - val_loss: 15.5532
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4667 - loss: 0.7470 - val_accuracy: 0.0000e+00 - val_loss: 14.3319
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4000 - loss: 0.7077 - val_accuracy: 0.0000e+00 - val_loss: 15.5484
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4667 - loss: 0.7301 - val_accuracy: 0.0000e+00 - val_loss: 15.4167
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4000 - loss: 0.7113 - val_accuracy: 0.0000e+00 - val_loss: 16.0143
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4667 - loss: 0.7497 - val_accuracy: 0.0000e+00 - val_loss: 15.5991
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4000 - loss: 0.7150 - val_accuracy: 0.0000e+00 - val_loss: 15.9933
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4667 - loss: 0.7869 - val_accuracy: 0.0000e+00 - val_loss: 15.5036
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4000 - loss: 0.7156 - val_accuracy: 0.0000e+00 - val_loss: 16.7814
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4667 - loss: 0.7724 - val_accuracy: 0.0000e+00 - val_loss: 16.0364
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4000 - loss: 0.7021 - val_accuracy: 0.0000e+00 - val_loss: 16.8536
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5333 - loss: 0.7639 - val_accuracy: 0.0000e+00 - val_loss: 15.3348
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3333 - loss: 0.7004 - val_accuracy: 0.0000e+00 - val_loss: 16.7382
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5333 - loss: 0.7427 - val_accuracy: 0.0000e+00 - val_loss: 16.5051
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3333 - loss: 0.7037 - val_accuracy: 0.0000e+00 - val_loss: 17.0757
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 0.7682 - val_accuracy: 0.0000e+00 - val_loss: 15.7194
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3333 - loss: 0.7156 - val_accuracy: 0.0000e+00 - val_loss: 17.0611
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 0.7464 - val_accuracy: 0.0000e+00 - val_loss: 16.5248
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3333 - loss: 0.6970 - val_accuracy: 0.0000e+00 - val_loss: 17.3699
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5333 - loss: 0.7533 - val_accuracy: 0.0000e+00 - val_loss: 15.8230
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.3333 - loss: 0.7020 - val_accuracy: 0.0000e+00 - val_loss: 17.4642
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4667 - loss: 0.7432 - val_accuracy: 0.0000e+00 - val_loss: 15.6496
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.4000 - loss: 0.7068 - val_accuracy: 0.0000e+00 - val_loss: 16.7529
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.4667 - loss: 0.7152 - val_accuracy: 0.0000e+00 - val_loss: 16.6642
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.4000 - loss: 0.7238 - val_accuracy: 0.0000e+00 - val_loss: 16.0906
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.5333 - loss: 0.7295 - val_accuracy: 0.0000e+00 - val_loss: 17.0103
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.4667 - loss: 0.7259 - val_accuracy: 0.0000e+00 - val_loss: 15.0733
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4667 - loss: 0.7499 - val_accuracy: 0.0000e+00 - val_loss: 16.6596
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.4000 - loss: 0.7129 - val_accuracy: 0.0000e+00 - val_loss: 15.4560
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4667 - loss: 0.7351 - val_accuracy: 0.0000e+00 - val_loss: 16.4297
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.3333 - loss: 0.7040 - val_accuracy: 0.0000e+00 - val_loss: 15.5397
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.5333 - loss: 0.7243 - val_accuracy: 0.0000e+00 - val_loss: 16.2738
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# Translated sentence: bonjour
